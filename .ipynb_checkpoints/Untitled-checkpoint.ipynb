# %%
#====================================================================
# for visualizing network
from vis.utils import utils
from vis.visualization import overlay
from keras import activations
import cv2

from vis.utils import utils  
from keras.models import load_model

import numpy as np
import matplotlib.cm as cm
from vis.visualization import visualize_cam

# for plot 
from vis.utils import utils
from matplotlib import pyplot as plt
from vis.visualization import visualize_cam

import csv 
#====================================================================
# Out:
# Using TensorFlow backend.

# %%
#====================================================================
#load model and swap last layer for linear. 
model = load_model('model_window_k2.h5')

# from Udacity class material, reads in lines for image names
lines = []
with open('/home/andrewrs/Desktop/udacity/data/train3/driving_log.csv') as csvfile:
        reader = csv.reader(csvfile)
        for line in reader:
            lines.append(line)
            
#=================================================
# rewrite as function!!! 
def image_mask(image):
    # make zeros
    mask = np.zeros(image.shape, dtype=np.uint8)
    # define the corners
    #cut top left and right corners, top and bottom
    corners = np.array([[(0, 80),(0, 25), (110,0), (210, 0), (320,25), (320, 80)]], dtype=np.int32)
    # get channel number
    num_channels = image.shape[2] 
    # define no color
    mask_color = (255,)*num_channels
    # get mask
    mask = cv2.fillPoly(mask, corners, mask_color)
    # from Masterfool: use cv2.fillConvexPoly if you know it's convex
    # Use the mask
    masked_image = cv2.bitwise_and(image, mask)
    # get correct color scheme !! for plotting and saving only 
    #out_image = cv2.cvtColor(masked_image, cv2.COLOR_RGB2BGR)
    return masked_image

# %%
lines_cut = lines[2900:3500]

# creates an image with attention overlay for each picture fed in. 
def attention_overlay(lines, out_loc='/home/andrewrs/Desktop/udacity/mod_data/', model = model):
    for line in lines:
        source_path = line[0]
        # split character modified because image data was collected on windows 10
        filename = source_path.split('\\')[-1]
        current_path = '/home/andrewrs/Desktop/udacity/data/train3/IMG/' + filename
        image = cv2.imread(current_path)
        crop_img = image[65:140,0:320,:]
        masked_image = image_mask(crop_img)
        grads = visualize_cam(model, layer_idx=-5, filter_indices=0, seed_input=masked_image, backprop_modifier='guided')        
        #heatmap = np.uint8(cm.jet(grads))
        out_image = overlay(grads, masked_image, alpha = 0.4)
        out_image = cv2.cvtColor(out_image, cv2.COLOR_RGB2BGR)
        file_path = out_loc + filename
        cv2.imwrite(file_path, out_image)
        del image
        del crop_img
        del out_image
    return 0
            
# speed it up 
#import multiprocessing as mp

#pool = mp.Pool(processes=8)
#pool.map(attention_overlay, lines_cut)
attention_overlay(lines_cut)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-a63842a676ac> in <module>()
#      27 #pool = mp.Pool(processes=8)
#      28 #pool.map(attention_overlay, lines_cut)
# ---> 29 attention_overlay(lines_cut)
#
# <ipython-input-8-a63842a676ac> in attention_overlay(lines, out_loc, model)
#      11         crop_img = image[60:160,0:320,:]
#      12         masked_image = image_mask(crop_img)
# ---> 13         grads = visualize_cam(model, layer_idx=-5, filter_indices=0, seed_input=masked_image, backprop_modifier='guided')
#      14         #heatmap = np.uint8(cm.jet(grads))
#      15         out_image = overlay(grads, masked_image, alpha = 0.4)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/vis/visualization/saliency.py in visualize_cam(model, layer_idx, filter_indices, seed_input, penultimate_layer_idx, backprop_modifier, grad_modifier)
#     237         (ActivationMaximization(model.layers[layer_idx], filter_indices), -1)
#     238     ]
# --> 239     return visualize_cam_with_losses(model.input, losses, seed_input, penultimate_layer, grad_modifier)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/vis/visualization/saliency.py in visualize_cam_with_losses(input_tensor, losses, seed_input, penultimate_layer, grad_modifier)
#     158     penultimate_output = penultimate_layer.output
#     159     opt = Optimizer(input_tensor, losses, wrt_tensor=penultimate_output, norm_grads=False)
# --> 160     _, grads, penultimate_output_value = opt.minimize(seed_input, max_iter=1, grad_modifier=grad_modifier, verbose=False)
#     161
#     162     # For numerical stability. Very small grad values along with small penultimate_output_value can cause
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/vis/optimizer.py in minimize(self, seed_input, max_iter, input_modifiers, grad_modifier, callbacks, verbose)
#     141
#     142             # 0 learning phase for 'test'
# --> 143             computed_values = self.compute_fn([seed_input, 0])
#     144             losses = computed_values[:len(self.loss_names)]
#     145             named_losses = zip(self.loss_names, losses)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     959                 'Cannot feed value of shape %r for Tensor %r, '
#     960                 'which has shape %r'
# --> 961                 % (np_val.shape, subfeed_t.name, str(subfeed_t.get_shape())))
#     962           if not self.graph.is_feedable(subfeed_t):
#     963             raise ValueError('Tensor %s may not be fed.' % subfeed_t)
#
# ValueError: Cannot feed value of shape (1, 3, 100, 320) for Tensor 'lambda_2_input_1:0', which has shape '(?, 75, 320, 3)'

# %%
           
lines_cut = lines[2000:3000]

short = lines[0:3]
images = []
measurements = []
for line in short:
        for i in range(3):
            source_path = line[i]
            # split character modified because image data was collected on windows 10
            filename = source_path.split('\\')[-1]
            current_path = '/home/andrewrs/Desktop/udacity/data/train3/IMG/' + filename
            image = cv2.imread(current_path)
            image_c = image[60:160,0:320,:]
            images.append(image)
            measurement = float(line[3])
            measurements.append(measurement)

# %%
# creates an image with attention overlay for each picture fed in. 
def attention_overlay(lines, out_loc='/home/andrewrs/Desktop/udacity/mod_data/', model = model):
    source_path = line[0]
    # split character modified because image data was collected on windows 10
    filename = source_path.split('\\')[-1]
    current_path = '/home/andrewrs/Desktop/udacity/data/train3/IMG/' + filename
    image = cv2.imread(current_path)
    crop_img = image[0:160, 0:320, 0:3]
    grads = visualize_cam(model, layer_idx=-2, filter_indices=0, seed_input=image, backprop_modifier='relu')        
    #heatmap = np.uint8(cm.jet(grads))
    out_image = overlay(grads, crop_img)
    out_image = cv2.cvtColor(out_image, cv2.COLOR_RGB2BGR)
    file_path = out_loc + filename
    #return file_path, result
    cv2.imwrite(file_path, out_image)
# speed it up 
import multiprocessing as mp

#pool = mp.Pool(processes=8)
#pool.map(attention_overlay, lines_cut)
#attention_overlay(lines_cut)

pool = mp.Pool(4)
pool.map(attention_overlay, lines_cut)
# make an io handler 
#cv2.imwrite(file_path, out_image)

#def io_handler():
#    pool = multiprocessing.Pool(4)
 #   for result in p.imap(attention_overaly, lines_cut):
 #       cv2.imwrite(file_path, out_image)




#io_handler()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-6c1f92c4eec7> in <module>()
#      22
#      23 pool = mp.Pool(4)
# ---> 24 pool.map(attention_overlay, lines_cut)
#      25 # make an io handler
#      26 #cv2.imwrite(file_path, out_image)
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     258         in a list that is returned.
#     259         '''
# --> 260         return self._map_async(func, iterable, mapstar, chunksize).get()
#     261
#     262     def starmap(self, func, iterable, chunksize=None):
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     600
#     601     def get(self, timeout=None):
# --> 602         self.wait(timeout)
#     603         if not self.ready():
#     604             raise TimeoutError
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     597
#     598     def wait(self, timeout=None):
# --> 599         self._event.wait(timeout)
#     600
#     601     def get(self, timeout=None):
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/anaconda3/envs/carnd-term1/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:

# %%
#====================================================================
#load model and swap last layer for linear. 
model = load_model('model_crop_k2.h5')

# from Udacity class material, reads in lines for image names
lines = []
with open('/home/andrewrs/Desktop/udacity/data/train3/driving_log.csv') as csvfile:
        reader = csv.reader(csvfile)
        for line in reader:
            lines.append(line)

            
lines_cut = lines[2000:3000]

# %%
#====================================================================
# plot picture
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 6)

# load example image from difficult part of track 
img1 = utils.load_img('/home/andrewrs/Desktop/udacity/data/train3/IMG/center_2017_09_06_10_42_37_667.jpg', target_size=(160, 320))

# plot image 
plt.imshow(img1)

# %%
out_loc = '/home/andrewrs/Desktop/udacity/mod_data/'
file_path = out_loc + 'att_' 
t_images[0]

# %%
i=0
out_loc = '/home/andrewrs/Desktop/udacity/mod_data/'
source_path = line[i]
# split character modified because image data was collected on windows 10
filename = source_path.split('\\')[-1]
current_path = '/home/andrewrs/Desktop/udacity/data/train3/IMG/' + filename
image = cv2.imread(current_path)
#crop_img = image[0:160, 0:320, 0:3]
grads = visualize_cam(model, layer_idx=-2, filter_indices=0, seed_input=image, backprop_modifier='relu')        

img1 = utils.load_img('/home/andrewrs/Desktop/udacity/data/train3/IMG/center_2017_09_06_10_42_37_667.jpg', target_size=(160, 320))
out_image = overlay(grads, crop_img)
file_path = out_loc + filename
#cv2.imwrite(file_path, out_image)
#plt.imshow(out_image)()

grads.shape

# %%
len(lines)

# %%
#====================================================================
# plot picture
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 6)

# load example image from difficult part of track 
img1 = utils.load_img('/home/andrewrs/Desktop/udacity/data/train3/IMG/center_2017_09_06_10_42_37_667.jpg', target_size=(160, 320))

# plot image 
plt.imshow(img1)

# %%
# 20 is the imagenet index corresponding to `ouzel`
filter_indices=1
crop_img = img1[0:160, 0:320, 0:3]
grads = visualize_cam(model, layer_idx=-1, filter_indices=0, seed_input=img1, backprop_modifier=
                     None)        
# Lets overlay the heatmap onto original image.    
test = np.uint8(cm.jet(grads))
#plt.imshow(overlay(jet_heatmap, crop_img))
tc = test[...,-1]
#jet_heatmap.shape
#img_BGRA.shape
#plt.imshow(overlay(tc, crop_img))
#plt.imshow(jet_heatmap)

#tc = test[...,-1]
plot.imshow()
#tc.shape

# %%
#====================================================================
# import libraries 
# for data read in and CNN
import csv 
import cv2
import numpy  as np
from keras.models import Sequential
from keras.layers import Flatten, Dense, Lambda, Cropping2D, Dropout
from keras.layers.convolutional import Conv2D
from keras.layers.pooling import MaxPooling2D 	
from keras.regularizers import l2
from keras.optimizers import Adam 

# for balancing the data by steering angle
import matplotlib.pyplot as plt
import pylab
import random
#====================================================================

# %%
lines = []
with open('/home/andrewrs/Desktop/udacity/data/train3/driving_log.csv') as csvfile:
	reader = csv.reader(csvfile)
	for line in reader:
		lines.append(line)

# %%
#====================================================================
# plot picture
# %matplotlib inline
plt.rcParams['figure.figsize'] = (18, 6)

# load example image from difficult part of track 
img1 = utils.load_img('/home/andrewrs/Desktop/udacity/data/train3/IMG/center_2017_09_06_10_42_37_667.jpg', target_size=(160, 320))

# plot image 
plt.imshow(img1)
# Out:
# /home/andrewrs/anaconda3/envs/carnd-term1/lib/python3.5/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
	
# from Udacity class material, reads in X
images = []
measurements = []
i=0
source_path = line[i]
# split character modified because image data was collected on windows 10
filename = source_path.split('\\')[-1]
current_path = '/home/andrewrs/Desktop/udacity/data/train3/IMG/' + filename
image = cv2.imread(current_path)
# add cropping
image_c = image[60:160,0:320,:]
#image_corners

# zero out corners

# original image
#source [https://stackoverflow.com/questions/15341538/numpy-opencv-2-how-do-i-crop-non-rectangular-region]
# -1 loads as-is so if it will be 3 or 4 channel as the original
#image = cv2.imread('image.png', -1)
# mask defaulting to black for 3-channel and transparent for 4-channel
# (of course replace corners with yours)

# make zeros
mask = np.zeros(image_c.shape, dtype=np.uint8)

# define the corners
#cut top left and right corners, top and bottom
corners = np.array([[(0, 80),(0, 25), (110,5), (210, 5), (320,25), (320, 80)]], dtype=np.int32)

# get channel number
num_channels = image.shape[2] 

# define no color
mask_color = (255,)*num_channels

# get mask
mask = cv2.fillPoly(mask, corners, mask_color)
# from Masterfool: use cv2.fillConvexPoly if you know it's convex

# Use the mask
masked_image = cv2.bitwise_and(image_c, mask)

# get correct color scheme
out_image = cv2.cvtColor(masked_image, cv2.COLOR_RGB2BGR)

#  plot check
plt.imshow(out_image)

#=================================================
# rewrite as function!!! 
def image_mask(image):
    # make zeros
    mask = np.zeros(image_c.shape, dtype=np.uint8)
    # define the corners
    #cut top left and right corners, top and bottom
    corners = np.array([[(0, 80),(0, 25), (110,5), (210, 5), (320,25), (320, 80)]], dtype=np.int32)
    # get channel number
    num_channels = image.shape[2] 
    # define no color
    mask_color = (255,)*num_channels
    # get mask
    mask = cv2.fillPoly(mask, corners, mask_color)
    # from Masterfool: use cv2.fillConvexPoly if you know it's convex
    # Use the mask
    masked_image = cv2.bitwise_and(image, mask)
    # get correct color scheme !! for plotting and saving only 
    #out_image = cv2.cvtColor(masked_image, cv2.COLOR_RGB2BGR)
    return masked_image
    



#plt.imshow(image_c)
